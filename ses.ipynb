# %% [markdown]
# # SES points with py3Dmol
#
# Минимальный ноутбук: определения молекул и py3Dmol-viewer для SES-точек, ребер локального surface-графа и нормалей к поверхности.

# %%
from pathlib import Path
import sys

import torch

ROOT = Path.cwd()
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from molecule.examples import MOLECULES, MOLECULE_NAMES, get_molecule
from molecule.visualize import (
    render_py3dmol_analytic_ses_points,
    render_py3dmol_points,
    render_py3dmol_sdf_ses_points,
    render_py3dmol_tiled_analytic_ses_points,
    sample_display_points,
)

torch.set_default_dtype(torch.float64)

# %% [markdown]
# ## Molecules

# %%
# Molecule definitions live in src/molecule/examples.py
MOLECULE_NAMES
# Out:
# ('H2O',
#  'CO2',
#  'NH3',
#  'CH4',
#  'Ethanol',
#  'Benzene',
#  'Naphthalene',
#  'Cyclohexane chair',
#  'Glucose chair',
#  '18-Crown-6 cavity',
#  'Porphyrin pore',
#  'Calixarene bowl',
#  'Cryptand cage',
#  'Octahedral probe cage',
#  'Closed carbon shell',
#  'Sealed nanotube capsule',
#  'Double chamber cage',
#  'C6H14',
#  'Methionine')

# %% [markdown]
# ## py3Dmol rendering

# %%
SELECTED_MOLECULE = MOLECULE_NAMES[0]
SHOW_SES_EDGES = True
SHOW_SES_NORMALS = True
SELECTED_MOLECULE
# Out:
# 'H2O'

# %%
tiled_analytic_py3dmol_view = render_py3dmol_tiled_analytic_ses_points(
    SELECTED_MOLECULE,
    point_area=0.05,
    tile_size="auto",
    tile_overlap="auto",
    atom_density_scale=1.55,
    pair_density_scale=1.55,
    probe_density_scale=1.55,
    dedup_tolerance=0.05,
    exact_accessibility=False,
    max_grid_points=500_000,
    max_probe_triples=5_000_000,
    color_by="block_type",
    show_edges=SHOW_SES_EDGES,
    show_normals=SHOW_SES_NORMALS,
)
# Out:
# <div id="3dmolviewer_17782803889672565"  style="position: relative; width: 760px; height: 580px;">
#         <p id="3dmolwarning_17782803889672565" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
# ...

# %%
# analytic_py3dmol_view = render_py3dmol_analytic_ses_points(
#     SELECTED_MOLECULE,
#     point_area=0.05,
#     show_edges=SHOW_SES_EDGES,
#     show_normals=SHOW_SES_NORMALS,
# )

# %%
# sdf_py3dmol_view = render_py3dmol_sdf_ses_points(
#     SELECTED_MOLECULE,
#     m=128,
#     smoothness=0.3,
#     max_grid_points=200_000,
#     show_edges=SHOW_SES_EDGES,
#     show_normals=SHOW_SES_NORMALS,
# )

# %%
# py3dmol_view = render_py3dmol_points(
#     SELECTED_MOLECULE,
#     m=500,
#     show_edges=SHOW_SES_EDGES,
#     show_normals=SHOW_SES_NORMALS,
# )
