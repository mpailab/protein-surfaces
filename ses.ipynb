# %% [markdown]
# # SES points with py3Dmol
#
# Минимальный ноутбук: определения молекул и один py3Dmol-viewer, где одновременно показаны спроецированные SES-точки и исходные валидные точки на атомных сферах.

# %%
from pathlib import Path
import sys

import torch

ROOT = Path.cwd()
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from molecule.examples import MOLECULES, MOLECULE_NAMES, get_molecule
from molecule.visualize import render_py3dmol_analytic_ses_points, render_py3dmol_points, render_py3dmol_sdf_ses_points, sample_display_points

torch.set_default_dtype(torch.float64)

# %% [markdown]
# ## Molecules

# %%
# Molecule definitions live in src/molecule/examples.py
MOLECULE_NAMES
# Out:
# ('H2O',
#  'CO2',
#  'NH3',
#  'CH4',
#  'Ethanol',
#  'Benzene',
#  'Naphthalene',
#  'Cyclohexane chair',
#  'Glucose chair',
#  '18-Crown-6 cavity',
#  'Porphyrin pore',
#  'Calixarene bowl',
#  'Cryptand cage',
#  'Octahedral probe cage',
#  'Closed carbon shell',
#  'Sealed nanotube capsule',
#  'Double chamber cage',
#  'C6H14',
#  'Methionine')

# %% [markdown]
# ## py3Dmol rendering

# %%
SELECTED_MOLECULE = MOLECULE_NAMES[0]
SELECTED_MOLECULE
# Out:
# 'H2O'

# %%
analytic_py3dmol_view = render_py3dmol_analytic_ses_points(SELECTED_MOLECULE, point_area=0.05)
# Out:
# <div id="3dmolviewer_17775542285040421"  style="position: relative; width: 760px; height: 580px;">
#         <p id="3dmolwarning_17775542285040421" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17775542285040421 = null;
# var warn = document.getElementById("3dmolwarning_17775542285040421");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17775542285040421 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17775542285040421"),{backgroundColor:"white"});
# viewer_17775542285040421.zoomTo();
# 	viewer_17775542285040421.setBackgroundColor("white");
# 	viewer_17775542285040421.addCylinder({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.9572, "y": 0.0, "z": 0.0}, "radius": 0.045, "color": "#777777", "opacity": 0.85});
# 	viewer_17775542285040421.addCylinder({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": -0.239, "y": 0.927, "z": 0.0}, "radius": 0.045, "color": "#777777", "opacity": 0.85});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.0, "y": 0.0, "z": 0.0}, "radius": 1.52, "color": "#e63946", "opacity": 0.34});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.9572, "y": 0.0, "z": 0.0}, "radius": 1.2, "color": "#8ecae6", "opacity": 0.34});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.239, "y": 0.927, "z": 0.0}, "radius": 1.2, "color": "#8ecae6", "opacity": 0.34});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.07975183297852868, "y": 0.0, "z": 1.5179063360881544}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.10178565854900605, "y": 0.09324400105420268, "z": 1.513719008264463}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.015569170549343576, "y": -0.17740266817065214, "z": 1.5095316804407712}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.1281170279707566, "y": 0.16710597591889162, "z": 1.5053443526170798}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.23494774062503668, "y": -0.04155894715524551, "z": 1.5011570247933885}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.22240872037625198, "y": -0.14147822254697648, "z": 1.496969696969697}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.0743397215865635, "y": 0.2765400588726184, "z": 1.4927823691460056}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.14167535453855135, "y": -0.27278727401950786, "z": 1.488595041322314}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.30716487189947506, "y": 0.11217611856705582, "z": 1.4844077134986227}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.3193311026257392, "y": 0.1318152370865659, "z": 1.4802203856749312}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.15383123097272436, "y": -0.32872840538617204, "z": 1.4760330578512397}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.11359789990816486, "y": 0.36216800540098587, "z": 1.4718457300275483}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.34214570743321226, "y": -0.1982804310199287, "z": 1.4676584022038568}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.4010944907064937, "y": -0.08817949862333707, "z": 1.4634710743801653}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.24460988703993375, "y": 0.347932393143283, "z": 1.4592837465564739}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.05647082179199305, "y": -0.43578143429610267, "z": 1.4550964187327824}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.34643140664390293, "y": 0.29197275627715996, "z": 1.450909090909091}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.46585943118065776, "y": 0.01926475006605016, "z": 1.4467217630853995}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.3395688003850541, "y": -0.3379163104812205, "z": 1.442534435261708}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.02270240719231152, "y": 0.4909604864267243, "z": 1.4383471074380165}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.32264380094233713, "y": -0.38663510478236696, "z": 1.434159779614325}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.5107410492511365, "y": 0.06871948580811657, "z": 1.4299724517906336}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.43244261637526077, "y": 0.30088230891345286, "z": 1.4257851239669421}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.11808418030489429, "y": -0.5248960205244215, "z": 1.4215977961432507}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.2729281032824974, "y": 0.47629593189187136, "z": 1.4174104683195594}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.5331679015476136, "y": -0.17009510259355218, "z": 1.4132231404958677}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.5175349645425853, "y": -0.2391142803831772, "z": 1.4090358126721763}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.22404875698401772, "y": 0.535353050904572, "z": 1.4048484848484848}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.1998153933522589, "y": -0.5555376960940174, "z": 1.4006611570247935}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": 0.5313060414912497, "y": 0.2792395649461406, "z": 1.3964738292011019}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.addSphere({"center": {"x": -0.5897235245783763, "y": 0.15544922849955617, "z": 1.3922865013774104}, "radius": 0.045, "color": "#2a9d8f", "opacity": 0.76});
# 	viewer_17775542285040421.add

# %%
sdf_py3dmol_view = render_py3dmol_sdf_ses_points(
    SELECTED_MOLECULE,
    m=128,
    smoothness=0.3,
    max_grid_points=200_000,
)

# %%
# py3dmol_view = render_py3dmol_points(SELECTED_MOLECULE, m=100)
